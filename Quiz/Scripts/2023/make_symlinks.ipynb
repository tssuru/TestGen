# %%
from pathlib import Path

# %%
root = Path('./ProgAll(offline)')
src = Path('../ProgAll(offline)')
dest = Path('./Mod2023_PM_3')

# %%
for p in root.iterdir():
    if p.is_dir():
        print(p)
        dest.joinpath(p.name).symlink_to(src.joinpath(p.name))
# Out:
# ProgAll(offline)/00Lex
# ProgAll(offline)/01Ar
# ProgAll(offline)/02Log
# ProgAll(offline)/03If
# ProgAll(offline)/04Assign
# ProgAll(offline)/05Invoke
# ProgAll(offline)/06Scope
# ProgAll(offline)/07Except
# ProgAll(offline)/08Cycles
# ProgAll(offline)/09Recursion
# ProgAll(offline)/10Indexing
# ProgAll(offline)/11ListOperations
# ProgAll(offline)/12SetOperations
# ProgAll(offline)/13Classes
# ProgAll(offline)/14Linked
# ProgAll(offline)/15BinTree
# ProgAll(offline)/16Graphs
# ProgAll(offline)/17Numpy
# ProgAll(offline)/18Regex
# ProgAll(offline)/Graphs
# ProgAll(offline)/Tasks
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 4
#       2 if p.is_dir():
#       3     print(p)
# ----> 4     dest.joinpath(p.name).symlink_to(src.joinpath(p.name))
#
# File /usr/local/lib/python3.11/pathlib.py:1198, in Path.symlink_to(self, target, target_is_directory)
# ...
