# %%
import pandas as pd

# %%
fname='1.csv'

# %%
data=pd.read_csv(fname, delimiter=':', header=None, names=('var', 'task', 'res'))
data.head()
# Out:
#          var  task   res
# 0  Variant 1     1    -2
# 1  Variant 1     2  BAAC
# 2  Variant 1     3   768
# 3  Variant 1     4    64
# 4  Variant 1     5   166

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var     920 non-null    object
#  1   task    920 non-null    int64
#  2   res     920 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 21.7+ KB

# %%
data['var']=data['var'].str.replace('Variant ','').astype(int)

# %%
data.tail()
# Out:
#      var  task                  res
# 915  115     4                   46
# 916  115     5               syntax
# 917  115     6  undefined behaviour
# 918  115     7              BA~A~B=
# 919  115     8                   -8

# %%
keys= data.pivot(columns='task', index='var', values='res')

# %%
keys.to_csv('2.csv')
