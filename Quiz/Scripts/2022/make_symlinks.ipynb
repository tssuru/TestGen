# %%
from pathlib import Path

# %%
root = Path('./ProgAll')
src = Path('../ProgAll')
dest = Path('./ExamSA')

# %%
for p in root.iterdir():
    if p.is_dir():
        print(p)
        dest.joinpath(p.name).symlink_to(src.joinpath(p.name))
